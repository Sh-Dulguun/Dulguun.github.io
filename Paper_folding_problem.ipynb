# %% [markdown]
# <a href="https://colab.research.google.com/github/Sh-Dulguun/Dulguun.github.io/blob/master/Paper_folding_problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **[Problem 1] Implementation using exponentiation arithmetic operators**
# Create a program that uses the exponentiation arithmetic operator.
# As a template, we have prepared a code that calculates the thickness of a sheet of paper when it is folded once. Rewrite the code to calculate the thickness when the paper is folded 43 times.

# %%
THICKNESS = 0.00008

folded_thickness = THICKNESS * 2 **43

print("Thickness: {} meters".format(folded_thickness))
# Out:
# Thickness: 703687441.77664 meters

# %% [markdown]
# # [Problem 2] Unit Conversion
# If the unit is meters, it's hard to feel the difference, so please convert the unit to ◯◯ 10,000 kilometers and display it.
#
# ​We have prepared a code converted to ◯◯ kilometers as a sample, so please refer to it when working on it. It is specified that up to 2 digits are displayed after the decimal point.

# %%
THICKNESS = 0.00008

folded_thickness = THICKNESS * 2 **43
print("Thickness: {: .2f} kilometers".format(folded_thickness / 1000))
# Out:
# Thickness:  703687.44 kilometers

# %% [markdown]
# ## **[Problem 3] Create using a for statement**
# Next, create a program that uses the for statement.
#
# Do not use exponentiation arithmetic operators. Only the four arithmetic operations+ , - , * , / ) are allowed.

# %%
number1 = [6, 14, 10]
number2 = [2, 4, 8]

add = []
sub = []
multi = []
div = []

for num in range(3):
    add.append( number1[num] + number2[num])
    sub.append( number1[num] - number2[num])
    multi.append( number1[num] * number2[num])
    div.append( number1[num] / number2[num])

print("\nThe result of Addition =  ", add)
print("The result of Subtraction =  ", sub)
print("The result of Multiplication =  ", multi)
print("The result of Division =  ", div)
# Out:
# The result of Addition =   [8, 18, 18]
# The result of Subtraction =   [4, 10, 2]
# The result of Multiplication =   [12, 56, 80]
# The result of Division =   [3.0, 3.5, 1.25]

# %% [markdown]
# # **[Question 4] Comparison of calculation time**
# At the beginning of the cell where you wrote the code you want to measure the execution time, %%timeitenter and execute it.

# %%
# %%timeit
THICKNESS = 0.00008

folded_thickness = THICKNESS * 2 **43

print("Thickness: {} meters".format(folded_thickness))
# Out:
# Streaming output truncated to the last 5000 lines.
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# ...

# %% [markdown]
# # **[Problem 5] Saving to a list**
# So far we've only used the final value after 43 diffractions, but we also need the process value to visualize it on the graph. Add code that records a total of 44 values ​​in the process to the code using the for statement.
#
#
# 1.   First, create an empty list.
# 2.   Then add the unfolded value to the list.
# 1.   Add the value of the process of folding the paper up to n times in the for statement to the list.

# %%
THICKNESS = 0.00008
folded_thickness = THICKNESS
process = []
process.append(folded_thickness)
for i in range(43):
  folded_thickness = folded_thickness*2
  process.append(folded_thickness)
print("Thickness : {: .2f} kilometer".format(folded_thickness / 1000))
print(process)
print(len(process))
# Out:
# Thickness :  703687.44 kilometer
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096, 0.08192, 0.16384, 0.32768, 0.65536, 1.31072, 2.62144, 5.24288, 10.48576, 20.97152, 41.94304, 83.88608, 167.77216, 335.54432, 671.08864, 1342.17728, 2684.35456, 5368.70912, 10737.41824, 21474.83648, 42949.67296, 85899.34592, 171798.69184, 343597.38368, 687194.76736, 1374389.53472, 2748779.06944, 5497558.13888, 10995116.27776, 21990232.55552, 43980465.11104, 87960930.22208, 175921860.44416, 351843720.88832, 703687441.77664]
# 44

# %% [markdown]
# # **[Problem 6] Displaying a line graph**
# Alibrary called Matplotlib is used for drawing graphs . Use the following template behind the code that records to the list.
#
# Briefly describe how the thickness is changing.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Display the graph. Title and axis label name.
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(process)  # Enter the variable name of the list in "List name"
plt.show()

# %% [markdown]
# ## **[Problem 7] Customizing graphs**
# Let's customize the graph to make it easier to see. Create at least 3 customized graphs. For example, the line color can be changed to red by rewriting as follows.
#
# << Customization example >>
# 1.   Make the line color other than blue and red.
# 2.   Make the line thicker.
# 1.   Make the line dotted.
# 2.   Change the font size of the value.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.tick_params(labelsize=20)
plt.plot(process, color='orange')
plt.show()
