# %% [markdown]
# <a href="https://colab.research.google.com/github/Sh-Dulguun/Dulguun.github.io/blob/master/Creating_dummy_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **[Problem 1] Creating random numbers**
# Create 500 random numbers with a two-dimensional normal distribution whose mean is (-3, 0) and whose covariance matrix is
#
# [
# 1.0
# 0.8
# 0.8
# 1.0
# ]
#
# Multidimensional normally distributed random numbers can be created by using np.random.multivariate_normal() .
#
# The shape of the created ndarray will be (500, 2).
#
# <Seed value>
#
# To ensure that the value does not change from one run to the next, we will fix the seed value of the random number using np.random.seed() . We will use a seed value of 0.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)
mean1 = [-3,0]
mean2 = [0,-3]
cov = ([1.0,0.8],[0.8,1.0])

rand_data1 = np.random.multivariate_normal(mean1, cov, 500)
rand_data2 = np.random.multivariate_normal(mean2, cov, 500)
print(rand_data1)
print(rand_data2)

# %% [markdown]
# # **[Problem 2] Visualization by scatter plot**
# Visualize the data points created in Problem 1 with a scatter plot.
#
# Scatter plots can be drawn by using matplotlib's plt.scatter() .

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)
mean1 = [-3,0]
mean2 = [0,-3]
cov = ([1.0,0.8],[0.8,1.0])

rand_data1 = np.random.multivariate_normal(mean1, cov, 500)
rand_data2 = np.random.multivariate_normal(mean2, cov, 500)

fig ,ax = plt.subplots()
ax.scatter(rand_data1[:,0], rand_data1[:,1])
fig.suptitle('scatter')
ax.axis('equal')
plt.show()

# %% [markdown]
# # **[Problem 3] Visualization by histogram**
# Visualize the data created in Problem 1 with a histogram.
#
# A histogram can be drawn by using plt.hist() .
#
# Create it for each dimension and create two histograms.
#
# The range of the horizontal axis of each histogram should be aligned using plt.xlim() .

# %%
import numpy as np
import matplotlib.pyplot as plt

fig , ax = plt.subplots()
ax.set_title('Histogram of x1')
ax.set_xlabel('x1')
ax.set_ylabel('frequency')
plt.xlim((-6,2))
ax.hist(rand_data1[:,0],bins=60)

fig, ax = plt.subplots()
ax.set_title('Histogram of x2')
ax.set_xlabel('x2')
ax.set_ylabel('frequency')
plt.xlim(-6,2)
ax.hist(rand_data1[:,1],bins=60)
plt.show()

# %% [markdown]
# # **[Problem 4] Addition of data**
# Create 500 new random numbers with a two-dimensional normal distribution whose mean is (0, -3) and whose covariance matrix is represented by the following.
#
# [
# 1.0
# 0.8
# 0.8
# 1.0
# ]
# Then, visualize the data of problems 1 and 4 as one scatter plot. As a legend, show 0for Problem 1 and1for Problem 4.

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.scatter(rand_data1[:,0],rand_data1[:,1],label=0)
ax.scatter(rand_data2[:,0],rand_data2[:,1],label=1)
plt.title('scatter')
plt.axis('equal')
plt.xlabel('x1')
plt.ylabel('x2')
plt.legend()
plt.show()

# %% [markdown]
# # **[Problem 5] Data combination**
# It is better to keep the data together so that it is easier to deal with later. Combine the ndarrays created in Problems 1 and 4 into  a single ndarray of (1000, 2). The concatenation can be done using np.concatenate() or  np.vstack() .

# %%
import numpy as np

#use np.concatenate()
combined_data1 = np.concatenate((rand_data1,rand_data2))
print('Combined data by np.concatenate shape {}'.format(combined_data1.shape))

#use np.vstask
combined_data = np.vstack((rand_data1,rand_data2))
print('Combined data by np.vstack shape {}'.format(combined_data.shape))
# Out:
# Combined data by np.concatenate shape (1000, 2)
# Combined data by np.vstack shape (1000, 2)

# %% [markdown]
# # **[Problem 6] Data combination**
# For each of the 1000 pieces of data that you have combined together, label them to indicate whether they are from question 1 or 4. Question 1 should be labeled 0 and Question 4 should be labeled 1 .
#
# Create a ndarray of (1000, 3) by adding a new column of labels containing 0s and 1s.
#
# Datasets used for machine learning often have this form

# %%
import numpy as np

label = np.empty((1000,1))
label[0:500] = 0
label[500:1000] = 1

combined_data = np.append(combined_data,label, axis = 1)
print(combined_data.shape)
print(combined_data)
# Out:
# (1000, 3)
# [[-4.80006782 -1.54698618  0.        ]
#  [-4.63714503 -0.21987973  0.        ]
#  [-4.46267867 -2.08076347  0.        ]
#  ...
#  [-0.2185878  -3.15676476  1.        ]
#  [-1.37970304 -4.27950068  1.        ]
#  [ 1.49786804 -2.33126243  1.        ]]
